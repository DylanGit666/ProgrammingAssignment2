# %% [markdown]
# <a href="https://colab.research.google.com/github/DylanGit666/ProgrammingAssignment2/blob/master/python_env_control.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
# !{sys.executable} -m pip install poetry

# After installing poetry, you can use it to add packages.
# For example, to add 'numpy', you would run:
# !poetry add numpy

# If you need to initialize a poetry project first (e.g., if you don't have a pyproject.toml yet),
# you would run:
# !poetry init
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.6/281.6 kB 16.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 338.6/338.6 kB 24.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 43.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.8/453.8 kB 24.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 89.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 27.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 55.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.20.0
#     Uninstalling filelock-3.20.0:
#       Successfully uninstalled filelock-3.20.0
# ...

# %% [markdown]
# # Task
# Initialize a Poetry project to manage dependencies and track package versions, then set up a Git repository and commit the Poetry configuration files (`pyproject.toml` and `poetry.lock`) to it. Finally, push these files to a GitHub repository to enable version control for your project's dependencies.

# %% [markdown]
# ## Initialize Poetry Project
#
# ### Subtask:
# Initialize a Poetry project in your current Colab environment.

# %% [markdown]
# **Reasoning**:
# The first instruction is to run `!poetry init` to initialize the project, which will prompt for project details.

# %%
import sys
# !{sys.executable} -m poetry init
# Out:
# This command will guide you through creating your pyproject.toml config.
#
# Package name [content]:  data-science-env
# Version [0.1.0]:  0.1.0
# Description []:  python env for data science work
# Author [None, n to skip]:  Dylan Dong
# License []:  None
# Compatible Python versions [>=3.12]:  >=3.12
#
# Would you like to define your main dependencies interactively? (yes/no) [yes] no
# Would you like to define your development dependencies interactively? (yes/no) [yes] no
# Generated file
#
# [project]
# name = "data-science-env"
# version = "0.1.0"
# description = "python env for data science work"
# authors = [
#     {name = "Dylan Dong"}
# ]
# license = {text = "None"}
# readme = "README.md"
# requires-python = ">=3.12"
# dependencies = [
# ]
#
#
# [build-system]
# requires = ["poetry-core>=2.0.0,<3.0.0"]
# build-backend = "poetry.core.masonry.api"
#
#
# Do you confirm generation? (yes/no) [yes] yes

# %%
# !poetry add numpy pandas xgboost
# Out:
# Creating virtualenv data-science-env-6R8_UNrD-py3.12 in /root/.cache/pypoetry/virtualenvs
# Using version ^2.4.0 for numpy
# Using version ^2.3.3 for pandas
# Using version ^3.1.2 for xgboost
#
# Updating dependencies
# Resolving dependencies... (0.9s)
#
# Package operations: 9 installs, 0 updates, 0 removals
#
#   - Installing numpy (2.4.0): Pending...
#   - Installing six (1.17.0): Pending...
#   - Installing six (1.17.0): Pending...
#   - Installing numpy (2.4.0): Downloading... 0%
#   - Installing six (1.17.0): Pending...
#   - Installing six (1.17.0): Downloading... 0%
#   - Installing six (1.17.0): Downloading... 100%
#   - Installing six (1.17.0): Installing...
#   - Installing six (1.17.0)
#   - Installing six (1.17.0)
#   - Installing numpy (2.4.0): Downloading... 50%
#   - Installing six (1.17.0)
#   - Installing six (1.17.0)
#   - Installing numpy (2.4.0): Downloading... 100%
#   - Installing six (1.17.0)
#   - Installing six (1.17.0)
# ...
